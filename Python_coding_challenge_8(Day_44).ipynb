# %% [markdown]
# Day 44 – range, for loop, enumerate, list comprehension

# %% [markdown]
# Project Title: Employee Hours Report

# %% [markdown]
# Scenario:
#
#  You are analyzing student exam scores to generate performance reports.

# %%
# Create a list of 10 random exam scores ranging from 0 to 100 using list comprehension
import random
exam_scores=[random.randint(0,100) for i in range(10)]

# %%
# Display each score with its index using the enumerate function.
print("Score with index")
for index,score in enumerate(exam_scores):
  print(f"Index: {index}, Score: {score}")
# Out:
# Score with index
# Index: 0, Score: 96
# Index: 1, Score: 2
# Index: 2, Score: 63
# Index: 3, Score: 52
# Index: 4, Score: 43
# Index: 5, Score: 67
# Index: 6, Score: 7
# Index: 7, Score: 15
# Index: 8, Score: 34
# Index: 9, Score: 74

# %%
# Find all scores greater than 75 and display them.
high_scores=[s for s in exam_scores if s>75]
print("Scores greater than 75: ",high_scores)
# Out:
# Scores greater than 75:  [96]

# %%
# Calculate and display the average score.
average_score=sum(exam_scores)/len(exam_scores)
print("Average Score: ",average_score)
# Out:
# Average Score:  45.3
