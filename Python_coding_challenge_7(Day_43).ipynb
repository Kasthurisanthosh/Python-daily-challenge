# %% [markdown]
# Day 43 – While Loop, else, break, continue

# %% [markdown]
# Project Title: Number Guessing Game

# %% [markdown]
# Scenario:
#
#  You are developing a fun guessing game where players have to guess a randomly selected number within a limited number of tries.

# %%
# Randomly choose a number between 1 and 20.
import random
secret_number = random.randint(1, 20)

# %%
# Let the user guess the number, allowing up to 5 attempts.
attempts = 5
count=0
print("Welcome to the number guessing game")
print("Enter the number between 1 and 20: ")
# Out:
# Welcome to the number guessing game
# Enter the number between 1 and 20:

# %%
# After each guess, tell them if their guess is too high, too low, or correct.
# If the guess is correct, break the loop and congratulate the player.
while count < attempts:
  guess = int(input("Enter the number: "))
  if 1 < guess >20:
    print("Invalid Range ! Please enter the number between 1 and 20") # Invalid entry
    continue
  count+=1
  if guess<secret_number:
    print("Too low")
  elif guess>secret_number:
    print("Too high")
  else:
    print(f"Congratulations! You guessed the correct number: {secret_number}")
    break
else:
    print(f"Out of attempts! The correct number was {secret_number}.")  # Out of attempts
# Out:
# Enter the number: 25
# Invalid Range ! Please enter the number between 1 and 20
# Enter the number: 1
# Too low
# Enter the number: 2
# Too low
# Enter the number: 3
# Too low
# Enter the number: 4
# Too low
# Enter the number: 5
# Too low
# Out of attempts! The correct number was 7.
