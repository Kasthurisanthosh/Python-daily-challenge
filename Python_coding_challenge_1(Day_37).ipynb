# %% [markdown]
# Day 37 – Introduction to Programming Languages and Python

# %% [markdown]
# Project Title: Student Profile Creator

# %% [markdown]
# Scenario:
#  You are helping to build a basic student information system for a local school. The school wants to store some basic details about each student and let them update their interests.

# %%
# Create variables to store the student’s name, age, and their favourite subjects they are enrolled in.
student_name = "Kasthuri"
age = 16
subjects = ["Maths", "English", "Science"]

# %%
# Display the student’s information in a user-friendly format.
print(f"Student Name: {student_name}")
print(f"Age: {age}")
print(f"Favourite Subjects: {subjects}")
# Out:
# Student Name: Kasthuri
# Age: 16
# Favourite Subjects: ['Maths', 'English', 'Science']

# %%
# Ask the student to enter their favourite subject and add it to their favourite subjects variable
favourite_subject = input("Enter your favourite subject: ")
subjects.append(favourite_subject)
# Out:
# Enter your favourite subject: Chemistry

# %%
# Display the updated list of subjects.
print(f"Updated Favourite Subjects: {subjects}")
# Out:
# Updated Favourite Subjects: ['Maths', 'English', 'Science', 'Chemistry']
